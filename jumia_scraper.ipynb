# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time


options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)


driver.get("https://www.jumia.co.ke/flash-sales/")
print("Page loaded!")
time.sleep(5)

driver.quit()
print("Browser closed.")
# Out:
# Page loaded!
# Browser closed.

# %%
driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)
driver.get("https://www.jumia.co.ke/flash-sales/")
time.sleep(3)
from bs4 import BeautifulSoup


soup = BeautifulSoup(driver.page_source, "html.parser")


product = soup.find("article", class_="prd")


name = product.find("h3", class_="name").text.strip()
new_price = product.find("div", class_="prc").text.strip()
old_price = product.find("div", class_="old").text.strip()
discount = product.find("div", class_="bdg _dsct _sm").text.strip()
rating = product.find("div", class_="stars _s").text.strip()


anchor = product.find("a", class_="core")
brand = anchor["data-gtm-brand"] if anchor else "N/A"

print(f"Name: {name}")
print(f"Brand: {brand}")
print(f"New Price: {new_price}")
print(f"Old Price: {old_price}")
print(f"Discount: {discount}")
print(f"Rating: {rating}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 16
#      12
#      13 product = soup.find("article", class_="prd")
#      14
#      15
# ---> 16 name = product.find("h3", class_="name").text.strip()
#      17 new_price = product.find("div", class_="prc").text.strip()
#      18 old_price = product.find("div", class_="old").text.strip()
#      19 discount = product.find("div", class_="bdg _dsct _sm").text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for article in articles:
    print(article.get("class"))
# Out:
# ['banner-pop', '_pp']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# ['prd', '_box', '_hvr']
# None
# ['-phs', '-bt']
# ['-phs', '-bt']
# ['-bt', '-phm']
# ['-phs', '-bt']
# ['-bt', '-phm']
# ['-phs', '-bt']
# ['-phs', '-bt']
# ['-bt', '-phm']
# ['-phs', '-bt']
# ['-phm', '-pvxs']
# ['-pts', '-phs']
# ['-pts', '-phs']
# ['prd', '_fb', '_p', 'col', 'c-prd']
# ['prd', '_fb', '_p', 'col', 'c-prd']
# ['prd', '_fb', '_p', '_dis', 'col', 'c-prd']
# ['prd', '_fb', '_p', '_dis', 'col', 'c-prd']
# ['prd', '_fb', '_p', 'col', 'c-prd']
# ['prd', '_fb', '_p', '_dis', 'col', 'c-prd']
# ['prd', '_fb', '_p', 'col', 'c-prd']
# ['prd', '_fb', '_p', 'col', 'c-prd']
# ...

# %%
product = soup.find("article", class_="prd _box _hvr")

name = product.find("h3", class_="name").text.strip()
new_price = product.find("div", class_="prc").text.strip()
old_price = product.find("div", class_="old").text.strip()
discount = product.find("div", class_="bdg _dsct _sm").text.strip()
rating_tag = product.find("div", class_="stars _s")
rating = rating_tag.text.strip() if rating_tag else "N/A"

anchor = product.find("a", class_="core")
brand = anchor["data-gtm-brand"] if anchor else "N/A"

print(f"Name: {name}")
print(f"Brand: {brand}")
print(f"New Price: {new_price}")
print(f"Old Price: {old_price}")
print(f"Discount: {discount}")
print(f"Rating: {rating}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 product = soup.find("article", class_="prd _box _hvr")
#       2
# ----> 3 name = product.find("h3", class_="name").text.strip()
#       4 new_price = product.find("div", class_="prc").text.strip()
#       5 old_price = product.find("div", class_="old").text.strip()
#       6 discount = product.find("div", class_="bdg _dsct _sm").text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
product = soup.find("article", class_="prd _box _hvr")
print(product)
# Out:
# <article class="prd _box _hvr"><a class="core" data-ga4-discount="1.04" data-ga4-index="1" data-ga4-is_second_chance="false" data-ga4-item_brand="MATIHO" data-ga4-item_category="Health &amp; Beauty" data-ga4-item_category2="Beauty &amp; Personal Care" data-ga4-item_category3="Hair Care" data-ga4-item_category4="Hair Cutting Tools" data-ga4-item_category5="Hair Clippers &amp; Accessories" data-ga4-item_id="GE840ST3X0II3NAFAMZ" data-ga4-item_name="  Electric hair clippers, bald head shaver, razor, hairdressing electric trimmer, oil head carving, " data-ga4-list="productfloor_1_flash-sales_en_KE" data-ga4-price="1.99" data-ga4-tags="COL_317|CP_1|CP_UN105|CP_UN146|CP_UN155|CP_UN219|DSC-CH|HDSC|JFB2S|NEWC|TW|XTR20%|ZF|ZF_90|ZF_97" data-gtm-brand="MATIHO" data-gtm-category="Health &amp; Beauty/Beauty &amp; Personal Care/Hair Care/Hair Cutting Tools/Hair Clippers &amp; Accessories" data-gtm-dimension23="162488" data-gtm-dimension26="" data-gtm-dimension27="" data-gtm-dimension28="1" data-gt
# ...

# %%
product = soup.find("article", class_="prd _box _hvr")

anchor = product.find("a", class_="core")
brand = anchor["data-gtm-brand"] if anchor else "N/A"

name = product.find("div", class_="name").text.strip()
new_price = product.find("div", class_="prc").text.strip()
old_price = product.find("div", class_="prc")["data-oprc"] if product.find("div", class_="prc") else "N/A"
discount = product.find("div", class_="bdg _dsct").text.strip()

print(f"Name: {name}")
print(f"Brand: {brand}")
print(f"New Price: {new_price}")
print(f"Old Price: {old_price}")
print(f"Discount: {discount}")
# Out:
# Name: MATIHO   Electric hair clippers, bald head shaver, razor, hairdressing electric trimmer, oil head carving, edging electric hair shears
# Brand: MATIHO
# New Price: KSh 302
# Old Price: KSh 460
# Discount: 34%

# %%
products = soup.find_all("article", class_="prd _box _hvr")
print(f"Found {len(products)} flash sale products")

for product in products:
    try:
        anchor = product.find("a", class_="core")
        brand = anchor["data-gtm-brand"] if anchor else "N/A"
        name = product.find("div", class_="name").text.strip()
        new_price = product.find("div", class_="prc").text.strip()
        old_price = product.find("div", class_="prc")["data-oprc"] if product.find("div", class_="prc") else "N/A"
        discount = product.find("div", class_="bdg _dsct").text.strip()

        print(f"{brand} | {name[:40]}... | {new_price} | {old_price} | {discount}")

    except Exception as e:
        print(f"Skipped a product: {e}")
# Out:
# Found 15 flash sale products
# MATIHO | MATIHO   Electric hair clippers, bald he... | KSh 302 | KSh 460 | 34%
# Kuhl | Kuhl KUHL K1 20,000mAh Power Bank – High... | KSh 690 | KSh 1,340 | 49%
# BLWOENS | BLWOENS Men's Formal Shoes Tuxedo Dress ... | KSh 799 | KSh 2,025 | 61%
# GUEETON | GUEETON 128GB Metal OTG Usb Flash Drive ... | KSh 632 | KSh 936 | 32%
# Kuhl | Kuhl KUHL K2 20,000mAh Power Bank – High... | KSh 2,025 | KSh 2,700 | 25%
# FUXING FASHION | FUXING FASHION Shoes For Women Breathabl... | KSh 392 | KSh 859 | 54%
# Generic | G03 Neckband Wireless Bluetooth In-Ear S... | KSh 299 | KSh 587 | 49%
# EAGEAT | EAGEAT Pen Flash Drive 3.0 128GB - Metal... | KSh 599 | KSh 806 | 26%
# Genera | Genera 2 Pieces Motorcycle Riding Full F... | KSh 644 | KSh 967 | 33%
# GUEETON | GUEETON GUEETON Wireless Earphones Bluet... | KSh 386 | KSh 1,560 | 75%
# GUEETON | GUEETON 128GB usb Flash Drive metal hook... | KSh 655 | KSh 1,215 | 46%
# ...
